# %% [markdown]
# # Credit Card Fraud Detection using Machine Learning
#
# ## Objective
# The goal of this project is to detect fraudulent credit card transactions using machine learning.
#
# Fraud detection systems help financial institutions prevent monetary losses and protect customers.

# %% [markdown]
# Importing the dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import StandardScaler

# %%
credit_card_dataset = pd.read_csv("data/creditcard.csv")

# %%
# first 5 rows of the dataset
credit_card_dataset.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_dataset.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %% [markdown]
# ## Dataset Description
#
# This dataset contains credit card transaction details.
#
# Each transaction is labeled as:
#
# 0 → normal transaction
# 1 → fraudulent transaction
#
# The dataset is highly imbalanced, with very few fraud cases compared to normal transactions.

# %% [markdown]
# 1--> FRAUD TRANSACTION
#
# 0--> LEGIT TRANSACTION

# %%
credit_card_dataset['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# ## Imbalanced Dataset
#
# Fraud detection datasets are highly imbalanced.
#
# Most transactions are normal, while only a small percentage are fraud cases.
#
# Special care is required to evaluate model performance correctly.

# %%
credit_card_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
credit_card_dataset.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
credit_card_dataset.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
credit_card_dataset.Amount.describe()
# Out:
# count    284807.000000
# mean         88.349619
# std         250.120109
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.165000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
legit = credit_card_dataset[credit_card_dataset.Class==0]
fraud = credit_card_dataset[credit_card_dataset.Class==1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
credit_card_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# Under-Sampling

# %% [markdown]
# Build a sample dataset containing similar distribution of normal transactions and fradualent transactions

# %%
legit_sample = legit.sample(n=492)

# %% [markdown]
# Concatenating two DataFrame

# %%
new_dataset = pd.concat([legit_sample,fraud],axis=0)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 120785   75961.0  1.158020 -1.047580  1.388790 -0.559393 -1.981272 -0.275442
# 253142  156107.0  2.053529 -0.148556 -1.253216  0.193158  0.101457 -0.628853
# 56844    47628.0 -1.414686  0.059341  2.046947 -0.364635  0.983982 -1.282949
# 266811  162490.0  1.940494 -0.501533  0.047406  0.595139 -0.976805 -0.395403
# 40752    40383.0 -0.445361  0.493110  1.542206  0.070795 -0.705776  0.799868
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 120785 -1.329513  0.187483 -0.414190  ... -0.068804  0.118353  0.043924
# 253142  0.036608 -0.128566  0.391065  ... -0.274983 -0.715418  0.275439
# 56844   0.926013 -0.622642 -0.040553  ... -0.022890  0.228532 -0.285090
# 266811 -0.808078  0.030049  1.332178  ...  0.023395  0.186586  0.283139
# 40752  -0.713618  0.816389  0.479808  ...  0.310237  0.929066 -0.046148
#
# ...

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %% [markdown]
# ## Imbalanced Dataset
#
# Fraud detection datasets are highly imbalanced.
#
# Most transactions are normal, while only a small percentage are fraud cases.
#
# Special care is required to evaluate model performance correctly.

# %%
new_dataset.groupby("Class").mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      97090.776423  0.069900  0.000115  0.077618  0.012730 -0.089193
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.057213 -0.002607 -0.033313 -0.120280  ...  0.009794  0.016714
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.037033  0.021354  0.024373 -0.039754 -0.018555 -0.012590 -0.006076
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       87.563516
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# ## Splitting Features and Target
#
# X → transaction features
# Y → fraud label

# %%
X = new_dataset.drop(columns="Class",axis=1)
Y = new_dataset['Class']

# %%
print("Feature shape:", X.shape)
print("Target shape:", Y.shape)
# Out:
# Feature shape: (984, 30)
# Target shape: (984,)

# %% [markdown]
# Splittting the data into training and test data

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=2,stratify=Y)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %% [markdown]
# ## Feature Scaling
#
# Feature scaling improves performance of Logistic Regression by normalizing feature values.

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# Logistic Regression

# %%
model = LogisticRegression()

# %%
# training the Logistic Regression Model with the training data
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Evaluation

# %% [markdown]
# Accuracy Score

# %%
training_data_prediction = model.predict(X_train)

training_data_accuracy = accuracy_score(training_data_prediction,Y_train)

print(f"The Accuracy on training data is {training_data_accuracy}")
# Out:
# The Accuracy on training data is 0.9491740787801779

# %%
test_data_prediction = model.predict(X_test)

test_data_accuracy = accuracy_score(test_data_prediction,Y_test)

print(f"The Accuracy on test data is {test_data_accuracy}")
# Out:
# The Accuracy on test data is 0.9441624365482234

# %%
print(classification_report(Y_test, test_data_prediction))

cm = confusion_matrix(Y_test, test_data_prediction)

plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d')

plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.title("Confusion Matrix")

plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95        99
#            1       0.99      0.90      0.94        98
#
#     accuracy                           0.94       197
#    macro avg       0.95      0.94      0.94       197
# weighted avg       0.95      0.94      0.94       197

# %%
y_prob = model.predict_proba(X_test)[:,1]

fpr, tpr, thresholds = roc_curve(Y_test, y_prob)

roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,4))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.3f}")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %%
Z = fraud.drop(columns="Class").iloc[0]

# %%
input_data = Z
input_data_as_numpy = np.asarray(input_data)

input_data_reshaped = input_data_as_numpy.reshape(1,-1)

prediction = model.predict(input_data_reshaped)

print(prediction)
# Out:
# [0]

# %% [markdown]
# ## Conclusion
#
# The model successfully detects fraudulent transactions.
#
# Key observations:
#
# fraud cases are very rare
#
# imbalanced dataset affects accuracy interpretation
#
# precision and recall are important metrics
#
# fraud detection helps prevent financial loss
#
# Future improvements:
#
# try Random Forest
#
# try XGBoost
#
# apply SMOTE for balancing dataset
#
# tune model hyperparameters
